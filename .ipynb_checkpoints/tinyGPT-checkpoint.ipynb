# %%
# Read file
try:
    with open('tinyshakespeare.txt', 'r', encoding='utf-8') as f:
        text = f.read()
except FileNotFoundError:
    # Get tinyshakespeare dataset to train the model on
    # !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/tinyshakespeare.txt
# Out:
# --2025-11-25 18:22:34--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/tinyshakespeare.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8002::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-11-25 18:22:34 ERROR 404: Not Found.

# %%
# Inspect
print(text[:100])

print("-----")
print("Length of dataset:{}".format(len(text)))
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You
# -----
# Length of dataset:1115394

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)

print("".join(chars))
print("{} characters".format(vocab_size))
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65 characters
